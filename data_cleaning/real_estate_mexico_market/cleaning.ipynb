# %%
#import pandas
import pandas as pd

# %%
#define path to our data file
path_1 = "./data/mexico-real-estate-1.csv"
df = pd.read_csv(path_1)
# Out:
# property_type        str
# state                str
# lat              float64
# lon              float64
# area_m2          float64
# price_usd            str
# dtype: object
